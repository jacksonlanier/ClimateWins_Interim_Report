# %% [markdown]
# # Script Contents
# #### .01 Import Libraries & Data
# #### .02 Explore Data
# #### .03 Scale Data

# %% [markdown]
# ## .01 Import Libraries & Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Create path to project folder
path = r'C:\Users\jacks\ClimateWins\02 Data Sets'

# %%
# Import Data
df = pd.read_csv(os.path.join(path, 'Dataset-weather-prediction-dataset-processed.csv'))

# %% [markdown]
# ## .02 Explore Data

# %%
# Check out the first few rows of the data
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Columns: 170 entries, DATE to VALENTIA_temp_max
# dtypes: float64(145), int64(25)
# memory usage: 29.8 MB

# %%
df.shape
# Out:
# (22950, 170)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# DATE                   0
# MONTH                  0
# BASEL_cloud_cover      0
# BASEL_wind_speed       0
# BASEL_humidity         0
#                       ..
# VALENTIA_snow_depth    0
# VALENTIA_sunshine      0
# VALENTIA_temp_mean     0
# VALENTIA_temp_min      0
# VALENTIA_temp_max      0
# Length: 170, dtype: int64

# %%
# There appear to be no missing values

# %% [markdown]
# ## .03 Scale Data

# %%
# Create a subset that does not contain the date and month columns since this will not need to be scaled
df2 = df.drop(columns=['DATE', 'MONTH'])

# %%
# Create scaler object using StandardScaler from sklearn.preprocessing
scaler = StandardScaler()

# %%
# Create new df with scaled data
df_scaled = pd.DataFrame(scaler.fit_transform(df2), columns=df2.columns)
df_scaled.head()
# Out:
#    BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  BASEL_pressure  \
# 0           0.660514          -0.02793        0.826097       -0.001949
# 1           0.244897          -0.02793        0.735760       -0.001949
# 2           1.076130          -0.02793        1.277781       -0.001949
# 3          -1.001953          -0.02793        1.458455       -0.001949
# 4           0.244897          -0.02793        1.729466       -0.001949
#
#    BASEL_global_radiation  BASEL_precipitation  BASEL_snow_depth  \
# 0               -1.101066            -0.265148         -0.179228
# 1               -1.058108             1.658760         -0.179228
# 2               -1.251420             0.155707         -0.179228
# 3               -0.821838            -0.445514         -0.179228
# 4               -0.746661            -0.164944         -0.179228
#
#    BASEL_sunshine  BASEL_temp_mean  BASEL_temp_min  ...  VALENTIA_cloud_cover  \
# ...

# %%
# Insert the 'DATE' column at the beginning (position 0)
df_scaled.insert(0, 'DATE', df['DATE'])

# Insert the 'month' column at the beginning (position 1)
df_scaled.insert(1, 'MONTH', df['MONTH'])

# %%
df_scaled.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1           0.660514          -0.02793        0.826097
# 1  19600102      1           0.244897          -0.02793        0.735760
# 2  19600103      1           1.076130          -0.02793        1.277781
# 3  19600104      1          -1.001953          -0.02793        1.458455
# 4  19600105      1           0.244897          -0.02793        1.729466
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0       -0.001949               -1.101066            -0.265148
# 1       -0.001949               -1.058108             1.658760
# 2       -0.001949               -1.251420             0.155707
# 3       -0.001949               -0.821838            -0.445514
# 4       -0.001949               -0.746661            -0.164944
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0         -0.179228       -0.902918  ...             -0.443701
# ...

# %%
# Export scaled data
df_scaled.to_pickle(os.path.join(path, 'weather_scaled.pkl'))
